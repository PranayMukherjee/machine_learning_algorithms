# %%
from numpy import *
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
iris=load_iris()
x=iris.data[:,1]
y=iris.data[:,3]
data=iris.data[:,:2]
k=3
centroid=zeros((k,2))
choice=random.randint(0,151,k)
print(choice)
for m in range(k):
    centroid[m]=array((data[choice[m]]))
print(centroid)
# Out:
# [140 142  50]
# [[ 6.7  3.1]
#  [ 5.8  2.7]
#  [ 7.   3.2]]

# %%
cluster_evaluator=zeros(k)
cluster=zeros(150)

def cluster_eval():
    for i in range(150):
        for j in range(k):
            cluster_evaluator[j]=linalg.norm(data[i]-centroid[j])
        for j in range(k):
            if(cluster_evaluator[j]==min(cluster_evaluator)):
                cluster[i]=j
    return(cluster)

def centroid_upd():
    for j in range(k):
        count=0
        val=0
        for i in range(150):
            if(cluster[i]==j):
                count=count+1
                val=val+data[i]
        centroid[j]=val/count
        return(centroid)
    
def distortion():
    s=0
    for i in range(150):
        s=s+(linalg.norm(data[i]-centroid[cluster[i]])**2)
    return(s)

# %%
sentinel_prev=distortion()
sentinel=0
for g in range(100):
    sentinel_prev=sentinel
    cluster=cluster_eval()
    centroid=centroid_upd()
    sentinel=distortion()
    print(sentinel)
    for i in range(150):
        if(cluster[i]==0):
            plt.scatter(x[i],y[i],color='b')
        elif(cluster[i]==1):
            plt.scatter(x[i],y[i],color='r')
        elif(cluster[i]==2):
            plt.scatter(x[i],y[i],color='y')
    plt.show()
# Out:
# E:\Python _ML\WinPython-64bit-3.5.3.0Qt5\python-3.5.3.amd64\lib\site-packages\ipykernel\__main__.py:27: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# 88.4993939394
# 87.1428205128
# 85.6065789474
# 81.8511904762
# 65.8963636364
# 40.5351923077
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632
# 38.632

# %%
for h in range(150):
    if(iris.target[h]==0):
        plt.scatter(x[h],y[h],color='b')
    elif(iris.target[h]==1):
        plt.scatter(x[h],y[h],color='r')
    elif(iris.target[h]==2):
        plt.scatter(x[h],y[h],color='y')
plt.show()

# %%
data[24]
# Out:
# array([ 4.8,  3.4])
